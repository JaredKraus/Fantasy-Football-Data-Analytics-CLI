# %%
import pandas as pd
import numpy as np

# %%
# read in data
ppr_2020 = pd.read_csv("./Fantasy Football Datasets/2020 PPR.csv")
std_2020 = pd.read_csv("./Fantasy Football Datasets/2020 Standard.csv")
adp_std_2021 = pd.read_csv("./Fantasy Football Datasets/2021 ADP Standard.csv")
adp_ppr_2021 = pd.read_csv("./Fantasy Football Datasets/2021 ADP PPR.csv")

# %% [markdown]
# # Formatting our 4 tables

# %%
offense_list = ['WR', 'RB', 'QB', 'TE'] # List containing desired posiitons

# %%
# 2020 PPR
ppr_2020.drop(ppr_2020.columns[[14,15,16,17]], axis=1, inplace=True)  # get rid of defense columns
ppr_2020 = ppr_2020[ppr_2020['POS'].isin(offense_list)]  # filter to only have desired positions
ppr_2020 = ppr_2020.rename({'RK': '2020 RK',}, axis=1)  # rename column
ppr_2020['Passing Pts'] = ppr_2020['PASSING YDS']/25 + ppr_2020['PASSING TD']*4 - ppr_2020['PASSING TD']*2
ppr_2020['Rushing Pts'] = ppr_2020['RUSHING YDS']/10 + ppr_2020['RUSHING TD']*6
ppr_2020['Receiving Pts'] = ppr_2020['RECEIVING YARDS']/10 + ppr_2020['RECEIVING TDS']*6 + ppr_2020['RECEIVING RECEPTIONS']
ppr_2020.head()
# Out:
#    2020 RK     ID              NAME TEAM POS  GAMES  PASSING YDS  PASSING TD  \
# 0        1  19801        Josh Allen  BUF  QB     16         4544          37
# 1        2   2593     Aaron Rodgers   GB  QB     16         4299          48
# 2        3  20889      Kyler Murray  ARI  QB     16         3971          26
# 3        4  18878      Alvin Kamara   NO  RB     15            0           0
# 4        5  18890   Patrick Mahomes   KC  QB     15         4740          38
#
#    PASSING INT  RUSHING YDS  RUSHING TD  RECEIVING RECEPTIONS  \
# 0           10          421           8                     1
# 1            5          149           3                     1
# 2           12          819          11                     0
# 3            0          932          16                    83
# 4            6          308           2                     0
#
#    RECEIVING YARDS  RECEIVING TDS  PTS/GAME  TOTAL POINTS  Passing Pts  \
# 0               12              1      24.8        396.06       255.76
# 1               -6              0      24.0        383.26       267.96
# 2                0              0      23.7        378.74       210.84
# 3              756              5      25.2        377.80         0.00
# 4                0              0      25.0        374.40       265.60
#
#    Rushing Pts  Receiving Pts
# 0         90.1            8.2
# 1         32.9            0.4
# 2        147.9            0.0
# 3        189.2          188.6
# 4         42.8            0.0

# %%
# 2020 STD
std_2020.drop(std_2020.columns[[14,15,16,17]], axis=1, inplace=True)
std_2020 = std_2020[std_2020['POS'].isin(offense_list)]
std_2020 = std_2020.rename({'RK': '2020 RK'}, axis=1)
std_2020['Passing Pts'] = std_2020['PASSING YDS']/25 + std_2020['PASSING TD']*4 - std_2020['PASSING TD']*2
std_2020['Rushing Pts'] = std_2020['RUSHING YDS']/10 + std_2020['RUSHING TD']*6
std_2020['Receiving Pts'] = std_2020['RECEIVING YARDS']/10 + std_2020['RECEIVING TDS']*6
std_2020.head()
# Out:
#    2020 RK     ID              NAME TEAM POS  GAMES  PASSING YDS  PASSING TD  \
# 0        1  19801        Josh Allen  BUF  QB     16         4544          37
# 1        2   2593     Aaron Rodgers   GB  QB     16         4299          48
# 2        3  20889      Kyler Murray  ARI  QB     16         3971          26
# 3        4  18890   Patrick Mahomes   KC  QB     15         4740          38
# 4        5  18857    Deshaun Watson  HOU  QB     16         4823          33
#
#    PASSING INT  RUSHING YDS  RUSHING TD  RECEIVING RECEPTIONS  \
# 0           10          421           8                     1
# 1            5          149           3                     1
# 2           12          819          11                     0
# 3            6          308           2                     0
# 4            7          444           3                     0
#
#    RECEIVING YARDS  RECEIVING TDS  PTS/GAME  TOTAL POINTS  Passing Pts  \
# 0               12              1      24.7        395.06       255.76
# 1               -6              0      23.9        382.26       267.96
# 2                0              0      23.7        378.74       210.84
# 3                0              0      25.0        374.40       265.60
# 4                0              0      23.1        369.32       258.92
#
#    Rushing Pts  Receiving Pts
# 0         90.1            7.2
# 1         32.9           -0.6
# 2        147.9            0.0
# 3         42.8            0.0
# 4         62.4            0.0

# %%
# ADP STD
adp_std_2021 = adp_std_2021[adp_std_2021['POS'].isin(offense_list)]
adp_std_2021 = adp_std_2021.rename({'RK': 'RK_ADP', 'PTS':'2021 PROJ PTS','POS RK':'2021 PROJ POS RK' }, axis=1)
adp_std_2021.drop(adp_std_2021.columns[[4,5]], axis=1, inplace=True)
print(adp_std_2021.shape)
adp_std_2021.head()
# Out:
# (252, 8)
#    RK_ADP     ID                  NAME TEAM POS 2021 PROJ POS RK  \
# 0       1  18877   Christian McCaffrey  CAR  RB              RB1
# 1       2  18872           Dalvin Cook  MIN  RB              RB2
# 2       3  17959         Derrick Henry  TEN  RB              RB3
# 3       4  19766        Saquon Barkley  NYG  RB              RB4
# 4       5  18878          Alvin Kamara   NO  RB              RB5
#
#    2021 PROJ PTS  ADP
# 0         271.71  1.3
# 1         262.77  2.4
# 2         269.30  2.8
# 3         230.61  4.3
# 4         216.46  4.9

# %%
# ADP PPR
adp_ppr_2021 = adp_ppr_2021[adp_ppr_2021['POS'].isin(offense_list)]
adp_ppr_2021 = adp_ppr_2021.rename({'RK': 'RK_ADP', 'PTS':'2021 PROJ PTS','POS RK':'2021 PROJ POS RK' }, axis=1)
adp_ppr_2021.drop(adp_ppr_2021.columns[[4,5]], axis=1, inplace=True)
print(adp_ppr_2021.shape)
adp_ppr_2021.head()
# Out:
# (245, 8)
#    RK_ADP     ID                  NAME TEAM POS 2021 PROJ POS RK  \
# 0       1  18877   Christian McCaffrey  CAR  RB              RB1
# 1       2  18872           Dalvin Cook  MIN  RB              RB2
# 2       3  17959         Derrick Henry  TEN  RB              RB3
# 3       4  19766        Saquon Barkley  NYG  RB              RB4
# 4       4  18878          Alvin Kamara   NO  RB              RB5
#
#    2021 PROJ PTS  ADP
# 0         361.41  1.3
# 1         318.07  2.6
# 2         293.10  4.0
# 3         285.61  4.5
# 4         292.66  4.5

# %% [markdown]
# # Joining Tables

# %%
std_merged = pd.merge(adp_std_2021,std_2020, on='ID',how="outer" )
std_merged['League Type'] = 'STD'  # add league type column
std_merged
# Out:
#      RK_ADP     ID                NAME_x TEAM_x POS_x 2021 PROJ POS RK  \
# 0       1.0  18877   Christian McCaffrey    CAR    RB              RB1
# 1       2.0  18872           Dalvin Cook    MIN    RB              RB2
# 2       3.0  17959         Derrick Henry    TEN    RB              RB3
# 3       4.0  19766        Saquon Barkley    NYG    RB              RB4
# 4       5.0  18878          Alvin Kamara     NO    RB              RB5
# ..      ...    ...                   ...    ...   ...              ...
# 261     NaN   4807                   NaN    NaN   NaN              NaN
# 262     NaN  13723                   NaN    NaN   NaN              NaN
# 263     NaN  11488                   NaN    NaN   NaN              NaN
# 264     NaN  16510                   NaN    NaN   NaN              NaN
# 265     NaN  19843                   NaN    NaN   NaN              NaN
#
#      2021 PROJ PTS  ADP  2020 RK            NAME_y  ... RUSHING TD  \
# 0           271.71  1.3      NaN               NaN  ...        NaN
# 1           262.77  2.4     14.0       Dalvin Cook  ...       16.0
# 2           269.30  2.8     11.0     Derrick Henry  ...       17.0
# 3           230.61  4.3      NaN               NaN  ...        NaN
# 4           216.46  4.9     13.0      Alvin Kamara  ...       16.0
# ..             ...  ...      ...               ...  ...        ...
# 261            NaN  NaN    194.0   Adrian Peterson  ...        7.0
# 262            NaN  NaN    240.0        Nick Foles  ...        1.0
# 263            NaN  NaN    282.0      Jimmy Graham  ...        0.0
# 264            NaN  NaN    284.0   Jerick McKinnon  ...        5.0
# 265            NaN  NaN    286.0      Hayden Hurst  ...        0.0
#
#     RECEIVING RECEPTIONS  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  \
# 0                    NaN              NaN            NaN       NaN
# 1                   44.0            361.0            1.0      21.0
# 2                   19.0            114.0            0.0      19.6
# 3                    NaN              NaN            NaN       NaN
# 4                   83.0            756.0            5.0      19.7
# ..                   ...              ...            ...       ...
# 261                 12.0            101.0            0.0       7.0
# 262                  0.0              0.0            0.0      11.6
# 263                 50.0            456.0            8.0       5.8
# 264                 33.0            253.0            1.0       5.8
# 265                 56.0            571.0            6.0       5.8
#
#      TOTAL POINTS  Passing Pts  Rushing Pts  Receiving Pts  League Type
# 0             NaN          NaN          NaN            NaN          STD
# 1          293.80         0.00        251.7           42.1          STD
# 2          314.10         0.00        304.7           11.4          STD
# 3             NaN          NaN          NaN            NaN          STD
# 4          294.80         0.00        189.2          105.6          STD
# ..            ...          ...          ...            ...          ...
# 261        112.50         0.00        102.4           10.1          STD
# 262        104.18        94.08          6.1            0.0          STD
# 263         93.60         0.00          0.0           93.6          STD
# 264         93.20         0.00         61.9           31.3          STD
# 265         93.10         0.00          0.0           93.1          STD
#
# [266 rows x 27 columns]

# %%
# investigate null values
is_NaN = std_merged.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = std_merged[row_has_NaN]
rows_with_NaN
# three null cases:
# case 1: outside of top 300 in 2020 but ranked in 2021 (ex CMC, saquon)
# case 2: rookie (no 2020 data)
# case 3: outside of top 300 ADP ranks but played 2020 and was inside top 300 (ex Jimmy Graham)
# Out:
#      RK_ADP     ID                NAME_x TEAM_x POS_x 2021 PROJ POS RK  \
# 0       1.0  18877   Christian McCaffrey    CAR    RB              RB1
# 3       4.0  19766        Saquon Barkley    NYG    RB              RB4
# 13     14.0  21688             Cam Akers    LAR    RB             RB11
# 21     22.0  18858             Joe Mixon    CIN    RB             RB15
# 24     25.0  19063         George Kittle     SF    TE              TE2
# ..      ...    ...                   ...    ...   ...              ...
# 261     NaN   4807                   NaN    NaN   NaN              NaN
# 262     NaN  13723                   NaN    NaN   NaN              NaN
# 263     NaN  11488                   NaN    NaN   NaN              NaN
# 264     NaN  16510                   NaN    NaN   NaN              NaN
# 265     NaN  19843                   NaN    NaN   NaN              NaN
#
#      2021 PROJ PTS   ADP  2020 RK            NAME_y  ... RUSHING TD  \
# 0           271.71   1.3      NaN               NaN  ...        NaN
# 3           230.61   4.3      NaN               NaN  ...        NaN
# 13          211.88  14.3      NaN               NaN  ...        NaN
# 21          195.68  21.1      NaN               NaN  ...        NaN
# 24          152.28  22.2      NaN               NaN  ...        NaN
# ..             ...   ...      ...               ...  ...        ...
# 261            NaN   NaN    194.0   Adrian Peterson  ...        7.0
# 262            NaN   NaN    240.0        Nick Foles  ...        1.0
# 263            NaN   NaN    282.0      Jimmy Graham  ...        0.0
# 264            NaN   NaN    284.0   Jerick McKinnon  ...        5.0
# 265            NaN   NaN    286.0      Hayden Hurst  ...        0.0
#
#     RECEIVING RECEPTIONS  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  \
# 0                    NaN              NaN            NaN       NaN
# 3                    NaN              NaN            NaN       NaN
# 13                   NaN              NaN            NaN       NaN
# 21                   NaN              NaN            NaN       NaN
# 24                   NaN              NaN            NaN       NaN
# ..                   ...              ...            ...       ...
# 261                 12.0            101.0            0.0       7.0
# 262                  0.0              0.0            0.0      11.6
# 263                 50.0            456.0            8.0       5.8
# 264                 33.0            253.0            1.0       5.8
# 265                 56.0            571.0            6.0       5.8
#
#      TOTAL POINTS  Passing Pts  Rushing Pts  Receiving Pts  League Type
# 0             NaN          NaN          NaN            NaN          STD
# 3             NaN          NaN          NaN            NaN          STD
# 13            NaN          NaN          NaN            NaN          STD
# 21            NaN          NaN          NaN            NaN          STD
# 24            NaN          NaN          NaN            NaN          STD
# ..            ...          ...          ...            ...          ...
# 261        112.50         0.00        102.4           10.1          STD
# 262        104.18        94.08          6.1            0.0          STD
# 263         93.60         0.00          0.0           93.6          STD
# 264         93.20         0.00         61.9           31.3          STD
# 265         93.10         0.00          0.0           93.1          STD
#
# [136 rows x 27 columns]

# %%
ppr_merged = pd.merge(adp_ppr_2021,std_2020, on='ID',how="outer" )
ppr_merged['League Type'] = 'PPR'  # add league type column
ppr_merged
# Out:
#      RK_ADP     ID                NAME_x TEAM_x POS_x 2021 PROJ POS RK  \
# 0       1.0  18877   Christian McCaffrey    CAR    RB              RB1
# 1       2.0  18872           Dalvin Cook    MIN    RB              RB2
# 2       3.0  17959         Derrick Henry    TEN    RB              RB3
# 3       4.0  19766        Saquon Barkley    NYG    RB              RB4
# 4       4.0  18878          Alvin Kamara     NO    RB              RB5
# ..      ...    ...                   ...    ...   ...              ...
# 253     NaN  19330                   NaN    NaN   NaN              NaN
# 254     NaN   4807                   NaN    NaN   NaN              NaN
# 255     NaN  13723                   NaN    NaN   NaN              NaN
# 256     NaN  19514                   NaN    NaN   NaN              NaN
# 257     NaN  11488                   NaN    NaN   NaN              NaN
#
#      2021 PROJ PTS  ADP  2020 RK            NAME_y  ... RUSHING TD  \
# 0           361.41  1.3      NaN               NaN  ...        NaN
# 1           318.07  2.6     14.0       Dalvin Cook  ...       16.0
# 2           293.10  4.0     11.0     Derrick Henry  ...       17.0
# 3           285.61  4.5      NaN               NaN  ...        NaN
# 4           292.66  4.5     13.0      Alvin Kamara  ...       16.0
# ..             ...  ...      ...               ...  ...        ...
# 253            NaN  NaN    167.0      Nick Mullens  ...        0.0
# 254            NaN  NaN    194.0   Adrian Peterson  ...        7.0
# 255            NaN  NaN    240.0        Nick Foles  ...        1.0
# 256            NaN  NaN    277.0       Keelan Cole  ...        0.0
# 257            NaN  NaN    282.0      Jimmy Graham  ...        0.0
#
#     RECEIVING RECEPTIONS  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  \
# 0                    NaN              NaN            NaN       NaN
# 1                   44.0            361.0            1.0      21.0
# 2                   19.0            114.0            0.0      19.6
# 3                    NaN              NaN            NaN       NaN
# 4                   83.0            756.0            5.0      19.7
# ..                   ...              ...            ...       ...
# 253                  0.0              0.0            0.0      11.6
# 254                 12.0            101.0            0.0       7.0
# 255                  0.0              0.0            0.0      11.6
# 256                 55.0            642.0            5.0       5.9
# 257                 50.0            456.0            8.0       5.8
#
#      TOTAL POINTS  Passing Pts  Rushing Pts  Receiving Pts  League Type
# 0             NaN          NaN          NaN            NaN          PPR
# 1          293.80         0.00        251.7           42.1          PPR
# 2          314.10         0.00        304.7           11.4          PPR
# 3             NaN          NaN          NaN            NaN          PPR
# 4          294.80         0.00        189.2          105.6          PPR
# ..            ...          ...          ...            ...          ...
# 253        116.28       121.48          0.8            0.0          PPR
# 254        112.50         0.00        102.4           10.1          PPR
# 255        104.18        94.08          6.1            0.0          PPR
# 256         94.40         0.00          0.2           94.2          PPR
# 257         93.60         0.00          0.0           93.6          PPR
#
# [258 rows x 27 columns]

# %%
final_df = pd.concat([ppr_merged, std_merged])
final_df
# Out:
#      RK_ADP     ID                NAME_x TEAM_x POS_x 2021 PROJ POS RK  \
# 0       1.0  18877   Christian McCaffrey    CAR    RB              RB1
# 1       2.0  18872           Dalvin Cook    MIN    RB              RB2
# 2       3.0  17959         Derrick Henry    TEN    RB              RB3
# 3       4.0  19766        Saquon Barkley    NYG    RB              RB4
# 4       4.0  18878          Alvin Kamara     NO    RB              RB5
# ..      ...    ...                   ...    ...   ...              ...
# 261     NaN   4807                   NaN    NaN   NaN              NaN
# 262     NaN  13723                   NaN    NaN   NaN              NaN
# 263     NaN  11488                   NaN    NaN   NaN              NaN
# 264     NaN  16510                   NaN    NaN   NaN              NaN
# 265     NaN  19843                   NaN    NaN   NaN              NaN
#
#      2021 PROJ PTS  ADP  2020 RK            NAME_y  ... RUSHING TD  \
# 0           361.41  1.3      NaN               NaN  ...        NaN
# 1           318.07  2.6     14.0       Dalvin Cook  ...       16.0
# 2           293.10  4.0     11.0     Derrick Henry  ...       17.0
# 3           285.61  4.5      NaN               NaN  ...        NaN
# 4           292.66  4.5     13.0      Alvin Kamara  ...       16.0
# ..             ...  ...      ...               ...  ...        ...
# 261            NaN  NaN    194.0   Adrian Peterson  ...        7.0
# 262            NaN  NaN    240.0        Nick Foles  ...        1.0
# 263            NaN  NaN    282.0      Jimmy Graham  ...        0.0
# 264            NaN  NaN    284.0   Jerick McKinnon  ...        5.0
# 265            NaN  NaN    286.0      Hayden Hurst  ...        0.0
#
#     RECEIVING RECEPTIONS  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  \
# 0                    NaN              NaN            NaN       NaN
# 1                   44.0            361.0            1.0      21.0
# 2                   19.0            114.0            0.0      19.6
# 3                    NaN              NaN            NaN       NaN
# 4                   83.0            756.0            5.0      19.7
# ..                   ...              ...            ...       ...
# 261                 12.0            101.0            0.0       7.0
# 262                  0.0              0.0            0.0      11.6
# 263                 50.0            456.0            8.0       5.8
# 264                 33.0            253.0            1.0       5.8
# 265                 56.0            571.0            6.0       5.8
#
#      TOTAL POINTS  Passing Pts  Rushing Pts  Receiving Pts  League Type
# 0             NaN          NaN          NaN            NaN          PPR
# 1          293.80         0.00        251.7           42.1          PPR
# 2          314.10         0.00        304.7           11.4          PPR
# 3             NaN          NaN          NaN            NaN          PPR
# 4          294.80         0.00        189.2          105.6          PPR
# ..            ...          ...          ...            ...          ...
# 261        112.50         0.00        102.4           10.1          STD
# 262        104.18        94.08          6.1            0.0          STD
# 263         93.60         0.00          0.0           93.6          STD
# 264         93.20         0.00         61.9           31.3          STD
# 265         93.10         0.00          0.0           93.1          STD
#
# [524 rows x 27 columns]

# %%
# combinie columns
# fill NA in one column with values from other
final_df.NAME_x.fillna(final_df.NAME_y, inplace=True)
final_df.drop(['NAME_y'], axis=1, inplace=True)
final_df.TEAM_x.fillna(final_df.TEAM_y, inplace=True)
final_df.drop(['TEAM_y'], axis=1, inplace=True)
final_df.POS_x.fillna(final_df.POS_y, inplace=True)
final_df.drop(['POS_y'], axis=1, inplace=True)
final_df = final_df.rename({'NAME_x': 'NAME', 'POS_x': 'POS', 'TEAM_x': 'TEAM', 'GAMES':'2020 GP', 'TOTAL POINTS':'2020 TTL PTS'}, axis=1)
final_df
# Out:
#      RK_ADP     ID                  NAME TEAM POS 2021 PROJ POS RK  \
# 0       1.0  18877   Christian McCaffrey  CAR  RB              RB1
# 1       2.0  18872           Dalvin Cook  MIN  RB              RB2
# 2       3.0  17959         Derrick Henry  TEN  RB              RB3
# 3       4.0  19766        Saquon Barkley  NYG  RB              RB4
# 4       4.0  18878          Alvin Kamara   NO  RB              RB5
# ..      ...    ...                   ...  ...  ..              ...
# 261     NaN   4807       Adrian Peterson  DET  RB              NaN
# 262     NaN  13723            Nick Foles  CHI  QB              NaN
# 263     NaN  11488          Jimmy Graham  CHI  TE              NaN
# 264     NaN  16510       Jerick McKinnon   SF  RB              NaN
# 265     NaN  19843          Hayden Hurst  ATL  TE              NaN
#
#      2021 PROJ PTS  ADP  2020 RK  2020 GP  ...  RUSHING TD  \
# 0           361.41  1.3      NaN      NaN  ...         NaN
# 1           318.07  2.6     14.0     14.0  ...        16.0
# 2           293.10  4.0     11.0     16.0  ...        17.0
# 3           285.61  4.5      NaN      NaN  ...         NaN
# 4           292.66  4.5     13.0     15.0  ...        16.0
# ..             ...  ...      ...      ...  ...         ...
# 261            NaN  NaN    194.0     16.0  ...         7.0
# 262            NaN  NaN    240.0      9.0  ...         1.0
# 263            NaN  NaN    282.0     16.0  ...         0.0
# 264            NaN  NaN    284.0     16.0  ...         5.0
# 265            NaN  NaN    286.0     16.0  ...         0.0
#
#      RECEIVING RECEPTIONS  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  \
# 0                     NaN              NaN            NaN       NaN
# 1                    44.0            361.0            1.0      21.0
# 2                    19.0            114.0            0.0      19.6
# 3                     NaN              NaN            NaN       NaN
# 4                    83.0            756.0            5.0      19.7
# ..                    ...              ...            ...       ...
# 261                  12.0            101.0            0.0       7.0
# 262                   0.0              0.0            0.0      11.6
# 263                  50.0            456.0            8.0       5.8
# 264                  33.0            253.0            1.0       5.8
# 265                  56.0            571.0            6.0       5.8
#
#      2020 TTL PTS  Passing Pts  Rushing Pts  Receiving Pts  League Type
# 0             NaN          NaN          NaN            NaN          PPR
# 1          293.80         0.00        251.7           42.1          PPR
# 2          314.10         0.00        304.7           11.4          PPR
# 3             NaN          NaN          NaN            NaN          PPR
# 4          294.80         0.00        189.2          105.6          PPR
# ..            ...          ...          ...            ...          ...
# 261        112.50         0.00        102.4           10.1          STD
# 262        104.18        94.08          6.1            0.0          STD
# 263         93.60         0.00          0.0           93.6          STD
# 264         93.20         0.00         61.9           31.3          STD
# 265         93.10         0.00          0.0           93.1          STD
#
# [524 rows x 24 columns]

# %%
# add indexing
final_df.set_index(['League Type', 'POS' ], inplace=True)
final_df.sort_index(inplace=True)
final_df
# Out:
#                  RK_ADP     ID               NAME TEAM 2021 PROJ POS RK  \
# League Type POS
# PPR         QB     22.0  18890    Patrick Mahomes   KC              QB1
#             QB     38.0  19801         Josh Allen  BUF              QB2
#             QB     44.0  20889       Kyler Murray  ARI              QB3
#             QB     51.0  18055       Dak Prescott  DAL              QB4
#             QB     52.0  19781      Lamar Jackson  BAL              QB5
# ...                 ...    ...                ...  ...              ...
# STD         WR    295.0  20529           Cam Sims  WAS            WR113
#             WR    296.0  22686        Dyami Brown  WAS            WR114
#             WR    297.0  16141    Willie Snead IV   LV            WR115
#             WR    299.0  20988   Preston Williams  MIA            WR116
#             WR    300.0  21730     Collin Johnson  JAX            WR117
#
#                  2021 PROJ PTS    ADP  2020 RK  2020 GP  PASSING YDS  ...  \
# League Type POS                                                       ...
# PPR         QB          396.81   20.9      4.0     15.0       4740.0  ...
#             QB          384.98   37.0      1.0     16.0       4544.0  ...
#             QB          358.09   43.2      3.0     16.0       3971.0  ...
#             QB          355.15   50.6    118.0      5.0       1856.0  ...
#             QB          351.83   51.0     10.0     15.0       2757.0  ...
# ...                        ...    ...      ...      ...          ...  ...
# STD         WR           48.98  230.0      NaN      NaN          NaN  ...
#             WR           48.04  231.0      NaN      NaN          NaN  ...
#             WR           47.51  232.0      NaN      NaN          NaN  ...
#             WR           46.48  234.0      NaN      NaN          NaN  ...
#             WR           46.28  235.0      NaN      NaN          NaN  ...
#
#                  RUSHING YDS  RUSHING TD  RECEIVING RECEPTIONS  \
# League Type POS
# PPR         QB         308.0         2.0                   0.0
#             QB         421.0         8.0                   1.0
#             QB         819.0        11.0                   0.0
#             QB          93.0         3.0                   1.0
#             QB        1005.0         7.0                   0.0
# ...                      ...         ...                   ...
# STD         WR           NaN         NaN                   NaN
#             WR           NaN         NaN                   NaN
#             WR           NaN         NaN                   NaN
#             WR           NaN         NaN                   NaN
#             WR           NaN         NaN                   NaN
#
#                  RECEIVING YARDS  RECEIVING TDS  PTS/GAME  2020 TTL PTS  \
# League Type POS
# PPR         QB               0.0            0.0      25.0        374.40
#             QB              12.0            1.0      24.7        395.06
#             QB               0.0            0.0      23.7        378.74
#             QB              11.0            1.0      26.9        134.64
#             QB               0.0            0.0      22.2        332.78
# ...                          ...            ...       ...           ...
# STD         WR               NaN            NaN       NaN           NaN
#             WR               NaN            NaN       NaN           NaN
#             WR               NaN            NaN       NaN           NaN
#             WR               NaN            NaN       NaN           NaN
#             WR               NaN            NaN       NaN           NaN
#
#                  Passing Pts  Rushing Pts  Receiving Pts
# League Type POS
# PPR         QB        265.60         42.8            0.0
#             QB        255.76         90.1            7.2
#             QB        210.84        147.9            0.0
#             QB         92.24         27.3            7.1
#             QB        162.28        142.5            0.0
# ...                      ...          ...            ...
# STD         WR           NaN          NaN            NaN
#             WR           NaN          NaN            NaN
#             WR           NaN          NaN            NaN
#             WR           NaN          NaN            NaN
#             WR           NaN          NaN            NaN
#
# [524 rows x 22 columns]

# %%
final_df.to_excel(r".\testExport.xlsx", index=True, header=True)  # export
